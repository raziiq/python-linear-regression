# %% [markdown]
# # Regression Models in Python
# ## Simple Linear and Multiple Linear Regression

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# import the dataset
df = pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ### Simple Linear Regression

# %%
# Create an object of Linear Regression
lr = LinearRegression()

# %%
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['wheel-base']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Yhat = lr.predict(X)
Yhat[0:5]
# Out:
# array([ 5397.30627159,  5397.30627159,  9916.07539362, 13975.30867274,
#        13668.95144413])

# %%
# Lets find out the Y intercept
lr.intercept_
# Out:
# -62460.81986606929

# %%
# Lets see the slope variable
lr.coef_
# Out:
# array([765.89307153])

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="wheel-base", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47613.48924781384)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['wheel-base'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.3418060603419337

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [ 5397.30627159  5397.30627159  9916.07539362 13975.30867274]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  41361996.58923002

# %% [markdown]
# #### So the R-squared is 0.3418060603419337 and MSE is  41361996.58923002 for Wheel-Base

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['length']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Yhat = lr.predict(X)
Yhat[0:5]
# Out:
# array([10801.45044105, 10801.45044105, 11870.44409178, 14275.67980594,
#        14275.67980594])

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="length", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47868.0011598258)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['length'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.4769675598807302

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [10801.45044105 10801.45044105 11870.44409178 14275.67980594]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  32868224.2433114

# %% [markdown]
# #### So the R-squared is 0.4769675598807302 and MSE is  32868224.2433114 for Length

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['width']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="width", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47915.52808081526)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['width'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.5643996171739719

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [ 8124.35937942  8124.35937942 12101.81063257 14090.53625914]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  27373849.04831775

# %% [markdown]
# #### So the R-squared is 0.5643996171739719 and MSE is  27373849.04831775 for Width

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['curb-weight']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="curb-weight", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47758.0553316559)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['curb-weight'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.6962476008164488

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [13108.85152621 13108.85152621 16634.03445191 10404.07480868]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  19088303.525747165

# %% [markdown]
# #### So the R-squared is 0.6962476008164488 and MSE is  19088303.525747165 for curb-weight

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['engine-size']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 53435.5258631886)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['engine-size'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.7609686443622008

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [13728.4631336  13728.4631336  17399.38347881 10224.40280408]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  15021126.02517414

# %% [markdown]
# #### So the R-squared is 0.7609686443622008 and MSE is 15021126.02517414 for engine-size

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['bore']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="bore", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47804.86127276696)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['bore'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.29501777036720744

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [15450.27312826 15450.27312826  2729.69660162 10941.71435932]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  44302250.17369163

# %% [markdown]
# #### So the R-squared is 0.29501777036720744 and MSE is 44302250.17369163 for bore

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['horsepower']]
Y = df['price']

# %%
lr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="horsepower", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47538.03259364832)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['horsepower'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.6554109795391572

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [14514.76823442 14514.76823442 21918.64247666 12965.1201372 ]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  21654544.39825428

# %% [markdown]
# #### So the R-squared is0.6554109795391572 and MSE is 21654544.39825428 for horsepower

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['city-mpg']]
Y = df['price']

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="city-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 48238.50332400353)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['city-mpg'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.4713797473570377

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16757.08312743 16757.08312743 18455.98957651 14208.72345381]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  33219371.63106507

# %% [markdown]
# #### So the R-squared is 0.4713797473570377 and MSE is 33219371.63106507 for city-mpg

# %%
# Lets do the same steps for other features as well
# Lets prepare the X (Independent variable) and Y (Dependent variable)
X = df[['highway-mpg']]
Y = df['price']

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Lets find out the regression using regplot from seaborn
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 48160.91343316586)

# %%
# Lets see how this feature does with Residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()

# The residual plot does not show a random spread which is not a good sign for the model

# %%
# Next step is to find the R-squared and Mean Square Error for this model.
# These values for each model will be compared to see which has model has the most appropriate values

lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.4965911884339175

# %%
# Lets find MSE. But first we need to find Yhat
Yhat=lr.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
# Finding MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639895

# %% [markdown]
# #### So the R-squared is 0.4965911884339175 and MSE is 31635042.944639895 for highway-mpg

# %%
# Lets put all the results in a dataframe for analysis
results = pd.DataFrame({
            'Feature': ['wheel-base','length','width','curb-weight','engine-size','bore','horsepower','city-mpg','highway-mpg'],
            'R-Squared': ['0.3418060603419337','0.4769675598807302','0.5643996171739719','0.6962476008164488','0.7609686443622008','0.29501777036720744','0.6554109795391572','0.4713797473570377','0.4965911884339175'],
            'MSE':['41361996.58923002','32868224.2433114','27373849.04831775','19088303.525747165','15021126.02517414','44302250.17369163','21654544.39825428','33219371.63106507','31635042.944639895']
   
}
)

# %%
# Lets sort the values by R-Squared
result_df = results.sort_values(by='R-Squared', ascending=False)
result_df
# Out:
#        Feature            R-Squared                 MSE
# 4  engine-size   0.7609686443622008   15021126.02517414
# 3  curb-weight   0.6962476008164488  19088303.525747165
# 6   horsepower   0.6554109795391572   21654544.39825428
# 2        width   0.5643996171739719   27373849.04831775
# 8  highway-mpg   0.4965911884339175  31635042.944639895
# 1       length   0.4769675598807302    32868224.2433114
# 7     city-mpg   0.4713797473570377   33219371.63106507
# 0   wheel-base   0.3418060603419337   41361996.58923002
# 5         bore  0.29501777036720744   44302250.17369163

# %% [markdown]
# #### Normally the models with high R-Squared value and low MSE value are considered better.
# #### This makes engine-size a good candidate for a good model

# %% [markdown]
# ### Multiple Linear Regression

# %%
# Lets now use Multiple Linear Regression to use multiple predictors of the price
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df['price']

# %%
lrm = LinearRegression()

# %%
lrm.fit(Z,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# In order to evaluate the model using visualization, we can use distribution plot as we have multiple variables
Y_hat = lrm.predict(Z)

# %%
plt.figure(figsize=(12, 10))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %%
# The model including looks pretty good as fitted values are overlapping actual values.
# Lets find R-Squared and MSE for this model
print('The R-square is: ', lrm.score(Z, Y))
# Out:
# The R-square is:  0.8093562806577457

# %%
Yhat=lrm.predict(Z)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [13699.11161184 13699.11161184 19051.65470233 10620.36193015]

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  11980366.87072649

# %% [markdown]
# #### So the R-squared is 0.8093562806577457 and MSE is 11980366.87072649 for this model which looks pretty good
# #### Lets call this MLR1 model

# %%
# Lets now use Multiple Linear Regression to use multiple predictors of the price for another model
Z = df[['length', 'width', 'engine-size', 'city-mpg']]
Y = df['price']

# %%
lrm.fit(Z,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# In order to evaluate the model using visualization, we can use distribution plot as we have multiple variables
Y_hat = lrm.predict(Z)

# %%
plt.figure(figsize=(12, 10))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %%
# The model including looks pretty good as fitted values are overlapping actual values.
# Lets find R-Squared and MSE for this model
print('The R-square is: ', lrm.score(Z, Y))
# Out:
# The R-square is:  0.8018559646857087

# %%
Yhat=lrm.predict(Z)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [13055.42360382 13055.42360382 17233.12532917 11473.19486377]

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  12451699.140687387

# %% [markdown]
# #### So the R-squared is 0.8018559646857087 and MSE is 12451699.140687387 for this model which looks pretty good
# #### Lets call this MLR2 model

# %%
# Lets now use Multiple Linear Regression to use multiple predictors of the price for another model
Z = df[['wheel-base', 'width', 'engine-size', 'bore']]
Y = df['price']

# %%
lrm.fit(Z,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# In order to evaluate the model using visualization, we can use distribution plot as we have multiple variables
Y_hat = lrm.predict(Z)

# %%
plt.figure(figsize=(12, 10))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %%
# The model including looks pretty good as fitted values are overlapping actual values.
# Lets find R-Squared and MSE for this model
print('The R-square is: ', lrm.score(Z, Y))
# Out:
# The R-square is:  0.7899669977069498

# %%
Yhat=lrm.predict(Z)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [12391.78308373 12391.78308373 15864.6503314  11045.96386982]

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  13198821.503862537

# %% [markdown]
# #### So the R-squared is 0.7899669977069498 and MSE is  13198821.503862537 for this model which looks pretty good
# #### Lets call this MLR3 model

# %%
# Lets put all the results in a dataframe for analysis
results = pd.DataFrame({
            'Model': ['SLR','MLR1','MLR2','MLR3'],
            'R-Squared': ['0.7609686443622008','0.8093562806577457','0.8018559646857087','0.7899669977069498'],
            'MSE':['15021126.02517414','11980366.87072649','12451699.140687387','13198821.503862537']
   
}
)

# %%
# Lets sort the values by R-Squared
result_df = results.sort_values(by='R-Squared', ascending=False)
result_df
# Out:
#   Model           R-Squared                 MSE
# 1  MLR1  0.8093562806577457   11980366.87072649
# 2  MLR2  0.8018559646857087  12451699.140687387
# 3  MLR3  0.7899669977069498  13198821.503862537
# 0   SLR  0.7609686443622008   15021126.02517414

# %% [markdown]
# ### From above comparison, based on R-Squared and MSE values, MLR1 seems to be the best of all these models
